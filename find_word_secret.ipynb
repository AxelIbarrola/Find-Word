# %%
import matplotlib.pyplot as plt
import cv2
from IPython.display import Image

# %%
Image('imagen_oculta_con_ruido.png')

# %%
sem_img = cv2.imread("imagen_oculta_con_ruido.png", cv2.IMREAD_COLOR)
plt.imshow(sem_img)

# %%
sem_img_rgb = cv2.cvtColor(sem_img, cv2.COLOR_BGR2RGB)
plt.imshow(sem_img_rgb)

# %%
imagen_bgr = cv2.imread("imagen_oculta_con_ruido.png", cv2.IMREAD_COLOR)
b, g, r = cv2.split(imagen_bgr)

# %%
plt.figure(figsize=[15, 5])

plt.subplot(142)
plt.imshow(r, cmap="OrRd");plt.title("Rojos")
plt.subplot(143)
plt.imshow(g, cmap="YlGn");plt.title("Verdes")
plt.subplot(144)
plt.imshow(b, cmap="Blues");plt.title("Azules")
# Out:
# Text(0.5, 1.0, 'Azules')
